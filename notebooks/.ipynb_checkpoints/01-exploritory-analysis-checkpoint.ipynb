# %%
df.loc[
    (df['Question'] == 'Average of 20 or more hours of care per week provided to a friend or family member') &
    (df['LocationAbbr'] == 'CA'), ['Question', 'LocationAbbr', 'Data_Value', 'Data_Value_Alt']
]
# generate state summary table
state_summary = df.groupby(['Question', 'LocationAbbr'], as_index = False)['Data_Value'].mean()
state_summary

# %% [markdown]
# # Exoloration and Analysis
# The objectives for this section are:
# - determine the shape of the data
# - determine the variables that will help us construct our heat maps and line graphs
# - assess consistency and completeness of those variables

# %%
import pandas as pd

# %%
# read in data and view
df = pd.read_csv("../data/raw/Alzheimers_Disease_and_Healthy_Aging_Data_20251104.csv")

# %%
df

# %%
df.columns
# Out:
# Index(['RowId', 'YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc',
#        'Datasource', 'Class', 'Topic', 'Question', 'Data_Value_Unit',
#        'DataValueTypeID', 'Data_Value_Type', 'Data_Value', 'Data_Value_Alt',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'Geolocation', 'ClassID', 'TopicID', 'QuestionID',
#        'LocationID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2'],
#       dtype='object')

# %%
df.loc[:, ['Question', 'YearStart', 'LocationDesc','Stratification1', 'Stratification2']].sort_values(by=['LocationDesc','Question'])
# Out:
#                                                  Question  YearStart  \
# 584     Average of 20 or more hours of care per week p...       2015
# 708     Average of 20 or more hours of care per week p...       2015
# 909     Average of 20 or more hours of care per week p...       2015
# 1238    Average of 20 or more hours of care per week p...       2015
# 2870    Average of 20 or more hours of care per week p...       2015
# ...                                                   ...        ...
# 247898  Severe joint pain due to arthritis among older...       2021
# 247975  Severe joint pain due to arthritis among older...       2021
# 248961  Severe joint pain due to arthritis among older...       2021
# 249133  Severe joint pain due to arthritis among older...       2021
# 249208  Severe joint pain due to arthritis among older...       2021
#
#        LocationDesc    Stratification1           Stratification2
# 584         Alabama        50-64 years       Black, non-Hispanic
# 708         Alabama            Overall  Native Am/Alaskan Native
# 909         Alabama  65 years or older                    Female
# 1238        Alabama        50-64 years                    Female
# 2870        Alabama  65 years or older                      Male
# ...             ...                ...                       ...
# 247898      Wyoming        50-64 years                  Hispanic
# 247975      Wyoming            Overall  Native Am/Alaskan Native
# 248961      Wyoming        50-64 years                       NaN
# 249133      Wyoming            Overall    Asian/Pacific Islander
# 249208      Wyoming  65 years or older  Native Am/Alaskan Native
#
# [284142 rows x 5 columns]

# %% [markdown]
# ### The data is in long format, with each question-state-year-stratification getting its own row. Because the objective is to create scatters, showing the relationship between life-style factors and subjective cognitive decline, by state, for a specific year, the data will need to get pivoted into a wide format. A wide format will also work nicely in creating the heat maps by state (LocationAbbr) and year (YearStart).
#
# ### Now that the shape of the data has been idenified, individual variables can be invesigated. The stratification variables will be considered first:

# %%
df['StratificationCategory1'].unique()
# Out:
# array(['Age Group'], dtype=object)

# %%
df['StratificationCategory2'].unique()
# Out:
# array(['Sex', nan, 'Race/Ethnicity'], dtype=object)

# %% [markdown]
# ### The stratification variables do not need to be considered in the data as the heat maps and graphs will not distiguish between age groups, sex, or race/ethnicity. Accordingly, the rows that are seperated by stratification will need to be reconciled into one row.
#
# ### Now the _Question_ field can be investigated to determine which lifestyle factors can be compared to SCD and which question can best represent the prevelance of SCD in the population.

# %%
# view all the questions we can filter by within the dashboard
df['Question'].unique()
# Out:
# array(['Mean number of days with activity limitations in the past month',
#        'Percentage of older adults with a lifetime diagnosis of depression',
#        'Percentage of older adults ever told they have arthritis',
#        'Percentage of older adults who are experiencing frequent mental distress',
#        'Percentage of older adults who reported influenza vaccine within the past year',
#        'Percentage of older adults who are currently obese, with a body mass index (BMI) of 30 or more',
#        'Percentage of older adults getting sufficient sleep (>6 hours)',
#        'Physically unhealthy days (mean number of days in past month)',
#        'Severe joint pain due to arthritis among older adults with doctor-diagnosed arthritis',
#        'Percentage of at risk adults (have diabetes, asthma, cardiovascular disease or currently smoke) who ever had a pneumococcal vaccine',
#        'Percentage of older adults who are eating 3 or more vegetables daily',
#        'Percentage of older adults who have smoked at least 100 cigarettes in their entire life and still smoke every day or some days',
#        'Percentage of older adults who have not had any leisure time physical activity in the past month',
#        'Percentage of older adults who provided care to a friend or family member for six months or more',
#        'Percentage of older adults who reported binge drinking within the past 30 days',
#        'Percentage of older adult women who have received a mammogram within the past 2 years',
#        'Percentage of older adults who self-reported that their health is "good", "very good", or "excellent"',
#        'Average of 20 or more hours of care per week provided to a friend or family member',
#        'Percentage of older adults who self-reported that their health is "fair" or "poor"',
#        'Fair or poor health among older adults with doctor-diagnosed arthritis',
#        'Percentage of older adults who are eating 2 or more fruits daily',
#        'Percentage of older adults who had a cholesterol screening within the past 5 years',
#        'Percentage of older adult women with an intact cervix who had a Pap test within the past 3 years',
#        'Percentage of older adults who have ever been told by a health professional that they have high blood pressure',
#        'Percentage of older adults who have fallen and sustained an injury within last year',
#        'Percentage of older adults who report having lost 5 or fewer teeth due to decay or gum disease',
#        'Percentage of older adults who provided care for a friend or family member within the past month',
#        'Percentage of older adults who have been told they have high blood pressure who report currently taking medication for their high blood pressure',
#        'Percentage of older adults currently not providing care who expect to provide care for someone with health problems in the next two years',
#        'Percentage of older adults who reported subjective cognitive decline or memory loss that interferes with their ability to engage in social activities or household chores',
#        'Percentage of older adults who reported that as a result of subjective cognitive decline or memory loss that they need assistance with day-to-day activities',
#        'Percentage of older adults who provided care for someone with dementia or other cognitive impairment within the past month',
#        'Percentage of older adults with subjective cognitive decline or memory loss who reported talking with a health care professional about it',
#        'Percentage of older adults who reported subjective cognitive decline or memory loss that is happening more often or is getting worse in the preceding 12 months',
#        'Percentage of older adults without diabetes who reported a blood sugar or diabetes test within 3 years',
#        'Percentage of older adults who had either a home blood stool test within the past year or a sigmoidoscopy or colonoscopy within the past 10 years',
#        'Percentage of older adult men who are up to date with select clinical preventive services',
#        'Percentage of older adults who report having a disability (includes limitations related to sensory or mobility impairments or a physical, mental, or emotional condition)',
#        'Percentage of older adult women who are up to date with select clinical preventive services'],
#       dtype=object)

# %%
df.groupby('Question', as_index=False)['Data_Value_Unit'].unique()
# Out:
#                                              Question Data_Value_Unit
# 0   Average of 20 or more hours of care per week p...             [%]
# 1   Fair or poor health among older adults with do...             [%]
# 2   Mean number of days with activity limitations ...        [Number]
# 3   Percentage of at risk adults (have diabetes, a...             [%]
# 4   Percentage of older adult men who are up to da...             [%]
# 5   Percentage of older adult women who are up to ...             [%]
# 6   Percentage of older adult women who have recei...             [%]
# 7   Percentage of older adult women with an intact...             [%]
# 8   Percentage of older adults currently not provi...             [%]
# 9   Percentage of older adults ever told they have...             [%]
# 10  Percentage of older adults getting sufficient ...             [%]
# 11  Percentage of older adults who are currently o...             [%]
# 12  Percentage of older adults who are eating 2 or...             [%]
# 13  Percentage of older adults who are eating 3 or...             [%]
# 14  Percentage of older adults who are experiencin...             [%]
# 15  Percentage of older adults who had a cholester...             [%]
# 16  Percentage of older adults who had either a ho...             [%]
# 17  Percentage of older adults who have been told ...             [%]
# 18  Percentage of older adults who have ever been ...             [%]
# 19  Percentage of older adults who have fallen and...             [%]
# 20  Percentage of older adults who have not had an...             [%]
# 21  Percentage of older adults who have smoked at ...             [%]
# 22  Percentage of older adults who provided care f...             [%]
# 23  Percentage of older adults who provided care f...             [%]
# 24  Percentage of older adults who provided care t...             [%]
# 25  Percentage of older adults who report having a...             [%]
# 26  Percentage of older adults who report having l...             [%]
# 27  Percentage of older adults who reported binge ...             [%]
# 28  Percentage of older adults who reported influe...             [%]
# 29  Percentage of older adults who reported subjec...             [%]
# 30  Percentage of older adults who reported subjec...             [%]
# 31  Percentage of older adults who reported that a...             [%]
# 32  Percentage of older adults who self-reported t...             [%]
# 33  Percentage of older adults who self-reported t...             [%]
# 34  Percentage of older adults with a lifetime dia...             [%]
# 35  Percentage of older adults with subjective cog...             [%]
# 36  Percentage of older adults without diabetes wh...             [%]
# 37  Physically unhealthy days (mean number of days...        [Number]
# 38  Severe joint pain due to arthritis among older...             [%]

# %% [markdown]
# ### The dataset includes several questions related to health and lifestyle. Of these, four are directly related the SCD:
# - 'Percentage of older adults who reported subjective cognitive decline or memory loss that interferes with their ability to engage in social activities or household chores'
# - 'Percentage of older adults who reported that as a result of subjective cognitive decline or memory loss that they need assistance with day-to-day activities'
# - 'Percentage of older adults with subjective cognitive decline or memory loss who reported talking with a health care professional about it'
# - 'Percentage of older adults who reported subjective cognitive decline or memory loss that is happening more often or is getting worse in the preceding 12 months'
#
# ### Because all the responses are reported the same (% of adult population), the values for each of these could be averaged into one SCD field. However, the question _reported talking with a health care professional about it_ is the most general of these and likely caputures the broadest population impacted by SCD. To futher asssess the relivance of each of these variables, we can compare the mean reported prevalence of each question:

# %%
rename_map = {
    'Percentage of older adults who reported subjective cognitive decline or memory loss that interferes with their ability to engage in social activities or household chores':
        'SCD: Social interference',
    'Percentage of older adults who reported that as a result of subjective cognitive decline or memory loss that they need assistance with day-to-day activities':
        'SCD: Needs assistance',
    'Percentage of older adults with subjective cognitive decline or memory loss who reported talking with a health care professional about it':
        'SCD: Talked to doctor',
    'Percentage of older adults who reported subjective cognitive decline or memory loss that is happening more often or is getting worse in the preceding 12 months':
        'SCD: Getting worse',
}

# Filter, rename, and group
df_scd_means = (
    df.loc[
        df['Question'].isin(rename_map.keys()),
        ['Question', 'Data_Value']
    ]
    .assign(question_condensed=lambda x: x['Question'].replace(rename_map))
    .groupby('question_condensed', as_index=False)['Data_Value']
    .mean()
)
df_scd_means
# Out:
#          question_condensed  Data_Value
# 0        SCD: Getting worse   11.670630
# 1     SCD: Needs assistance   33.747969
# 2  SCD: Social interference   39.190714
# 3     SCD: Talked to doctor   44.301677

# %%
questions_to_remove = ['Percentage of older adults who reported subjective cognitive decline or memory loss that is happening more often or is getting worse in the preceding 12 months', 'Percentage of older adults who reported that as a result of subjective cognitive decline or memory loss that they need assistance with day-to-day activities', 'Percentage of older adults who reported subjective cognitive decline or memory loss that interferes with their ability to engage in social activities or household chores']

# %% [markdown]
# ### As anticipated, _reported talking with a health care professional about it_ captures more of the population than the other questions. Due to the range in reported means, it would not be appropriate to combine them all into a single SCD indicator. The questions _SCD: Social interference_, _SCD: Needs assistance_, and _SCD: Getting worse_ likely capture subsets of reports captured in _SCD: Talked to doctor_, where symptoms are more severe or progressing. Due to this, these questions have been saved to a variable so they can be removed later.
#
# ### Now we will look into the _LocationAbbr_ and _LocationDesc_ values to assess consitency and completeness

# %%
df['LocationAbbr'].unique()
# Out:
# array(['GU', 'MA', 'MDW', 'MN', 'MO', 'NRE', 'OK', 'PR', 'SOU', 'TN',
#        'US', 'UT', 'AK', 'DC', 'MI', 'NJ', 'MD', 'NV', 'NH', 'MS', 'KY',
#        'ME', 'MT', 'NM', 'SD', 'NY', 'OH', 'ND', 'OR', 'SC', 'VI', 'WEST',
#        'CA', 'CO', 'FL', 'HI', 'RI', 'TX', 'NC', 'PA', 'DE', 'WA', 'VT',
#        'WY', 'VA', 'KS', 'IA', 'LA', 'IL', 'AL', 'AZ', 'ID', 'AR', 'GA',
#        'IN', 'NE', 'CT', 'WV', 'WI'], dtype=object)

# %%
df['LocationAbbr'].isna().sum()
# Out:
# 0

# %%
df['LocationDesc'].unique()
# Out:
# array(['Guam', 'Massachusetts', 'Midwest', 'Minnesota', 'Missouri',
#        'Northeast', 'Oklahoma', 'Puerto Rico', 'South', 'Tennessee',
#        'United States, DC & Territories', 'Utah', 'Alaska',
#        'District of Columbia', 'Michigan', 'New Jersey', 'Maryland',
#        'Nevada', 'New Hampshire', 'Mississippi', 'Kentucky', 'Maine',
#        'Montana', 'New Mexico', 'South Dakota', 'New York', 'Ohio',
#        'North Dakota', 'Oregon', 'South Carolina', 'Virgin Islands',
#        'West', 'California', 'Colorado', 'Florida', 'Hawaii',
#        'Rhode Island', 'Texas', 'North Carolina', 'Pennsylvania',
#        'Delaware', 'Washington', 'Vermont', 'Wyoming', 'Virginia',
#        'Kansas', 'Iowa', 'Louisiana', 'Illinois', 'Alabama', 'Arizona',
#        'Idaho', 'Arkansas', 'Georgia', 'Indiana', 'Nebraska',
#        'Connecticut', 'West Virginia', 'Wisconsin'], dtype=object)

# %%
df['LocationDesc'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### There are no missing values in either of fields. The inconsistent _LocacionDesc_ are saved to a variable so these rows can be removed in the cleaning phase:

# %%
locations_to_remove = ['Midwest', 'Northeast','South', 'United States, DC & Territories', 'West']

# %%
column_for_analysis = ['RowId', 'YearStart', 'LocationDesc', 'Question', 'Data_Value']

# %%
df['YearStart'].isna().sum()
# Out:
# 0

# %% [markdown]
# # Data Cleaning
# The objective for this section is to wrange out dataset into a format that can be imported into Tableau. The wranged dataset should:
#     - Include only the variables/field we will need for our visualation
#     - Filter out inconsistent/irrelevant rows
#     - Reshape the data to include one row per _LocationDesc_-_Question_-_YearStart_

# %%
# reduce df down to the relevant fields
df_viz_long = df[column_for_analysis]
df_viz_long
# Out:
#                                            RowId  YearStart   LocationDesc  \
# 0           BRFSS~2015~2015~66~Q35~TOC03~AGE~SEX       2015           Guam
# 1           BRFSS~2015~2015~25~Q27~TMC03~AGE~SEX       2015  Massachusetts
# 2         BRFSS~2015~2015~9002~Q43~TOC11~AGE~SEX       2015        Midwest
# 3           BRFSS~2015~2015~27~Q03~TMC01~AGE~SEX       2015      Minnesota
# 4       BRFSS~2015~2015~29~Q43~TOC11~AGE~OVERALL       2015       Missouri
# ...                                          ...        ...            ...
# 284137     BRFSS~2022~2022~53~Q16~TNC03~AGE~RACE       2022     Washington
# 284138     BRFSS~2022~2022~55~Q33~TOC08~AGE~RACE       2022      Wisconsin
# 284139     BRFSS~2022~2022~56~Q10~TSC10~AGE~RACE       2022        Wyoming
# 284140      BRFSS~2022~2022~51~Q07~TOC05~AGE~SEX       2022       Virginia
# 284141   BRFSS~2022~2022~9004~Q03~TMC01~AGE~RACE       2022           West
#
#                                                  Question  Data_Value
# 0       Mean number of days with activity limitations ...         5.9
# 1       Percentage of older adults with a lifetime dia...        13.0
# 2       Percentage of older adults ever told they have...        32.0
# 3       Percentage of older adults who are experiencin...         5.8
# 4       Percentage of older adults ever told they have...        46.8
# ...                                                   ...         ...
# 284137  Percentage of older adults who have not had an...        42.2
# 284138  Percentage of older adults who self-reported t...         NaN
# 284139  Percentage of older adult men who are up to da...         NaN
# 284140  Percentage of older adults who report having l...        70.3
# 284141  Percentage of older adults who are experiencin...         7.0
#
# [284142 rows x 5 columns]

# %%
# remove rows with inconsistent LocationDesc and irrelevant Questions
df_viz_long_filtered = df.loc[
    (~df['Question'].isin(questions_to_remove)) &
    (~df['LocationDesc'].isin(locations_to_remove))
]

# %%
# combine the different stratifications into one row
data_viz_long_grouped = df_viz_long_filtered.groupby(['YearStart', 'LocationDesc', 'Question'], as_index = False)['Data_Value'].mean()#['RowId'].min()
data_viz_long_grouped
# Out:
#        YearStart LocationDesc  \
# 0           2015      Alabama
# 1           2015      Alabama
# 2           2015      Alabama
# 3           2015      Alabama
# 4           2015      Alabama
# ...          ...          ...
# 10137       2022      Wyoming
# 10138       2022      Wyoming
# 10139       2022      Wyoming
# 10140       2022      Wyoming
# 10141       2022      Wyoming
#
#                                                 Question  Data_Value
# 0      Average of 20 or more hours of care per week p...   33.500000
# 1      Fair or poor health among older adults with do...   43.846667
# 2      Mean number of days with activity limitations ...    7.546667
# 3      Percentage of at risk adults (have diabetes, a...   54.573333
# 4      Percentage of older adults currently not provi...   19.340000
# ...                                                  ...         ...
# 10137  Percentage of older adults who self-reported t...   20.438462
# 10138  Percentage of older adults who self-reported t...   79.561538
# 10139  Percentage of older adults with a lifetime dia...   17.358333
# 10140  Percentage of older adults without diabetes wh...   83.376923
# 10141  Physically unhealthy days (mean number of days...    5.084615
#
# [10142 rows x 4 columns]

# %%
data_viz_wide = data_viz_long_grouped.pivot(
    index = ['YearStart', 'LocationDesc'],
    columns = 'Question',
    values = 'Data_Value'
)
data_viz_wide
# Out:
# Question                 Average of 20 or more hours of care per week provided to a friend or family member  \
# YearStart LocationDesc
# 2015      Alabama                                                33.500000
#           Alaska                                                       NaN
#           Arizona                                                      NaN
#           Arkansas                                                     NaN
#           California                                                   NaN
# ...                                                                    ...
# 2022      Virginia                                               39.426667
#           Washington                                             33.253333
#           West Virginia                                                NaN
#           Wisconsin                                              27.676923
#           Wyoming                                                      NaN
#
# Question                 Fair or poor health among older adults with doctor-diagnosed arthritis  \
# YearStart LocationDesc
# 2015      Alabama                                                43.846667
#           Alaska                                                 32.813333
#           Arizona                                                40.593333
#           Arkansas                                               45.780000
#           California                                             38.633333
# ...                                                                    ...
# 2022      Virginia                                               30.433333
#           Washington                                             31.462500
#           West Virginia                                          43.350000
#           Wisconsin                                              32.456250
#           Wyoming                                                28.776923
#
# Question                 Mean number of days with activity limitations in the past month  \
# YearStart LocationDesc
# 2015      Alabama                                                 7.546667
#           Alaska                                                  5.800000
#           Arizona                                                 6.375000
#           Arkansas                                                8.060000
#           California                                              6.340000
# ...                                                                    ...
# 2022      Virginia                                                5.973333
#           Washington                                              6.054167
#           West Virginia                                           8.325000
#           Wisconsin                                               6.994118
#           Wyoming                                                 5.883333
#
# Question                 Percentage of at risk adults (have diabetes, asthma, cardiovascular disease or currently smoke) who ever had a pneumococcal vaccine  \
# YearStart LocationDesc
# 2015      Alabama                                                54.573333
#           Alaska                                                 56.606667
#           Arizona                                                57.676471
#           Arkansas                                               57.226667
#           California                                             55.680000
# ...                                                                    ...
# 2022      Virginia                                               58.506250
#           Washington                                             57.237500
#           West Virginia                                          58.433333
#           Wisconsin                                              58.452941
#           Wyoming                                                52.469231
#
# Question                 Percentage of older adult men who are up to date with select clinical preventive services  \
# YearStart LocationDesc
# 2015      Alabama                                                      NaN
#           Alaska                                                       NaN
#           Arizona                                                      NaN
#           Arkansas                                                     NaN
#           California                                                   NaN
# ...                                                                    ...
# 2022      Virginia                                               45.250000
#           Washington                                             40.516667
#           West Virginia                                          41.411111
#           Wisconsin                                              41.690000
#           Wyoming                                                31.488889
#
# Question                 Percentage of older adult women who are up to date with select clinical preventive services  \
# YearStart LocationDesc
# 2015      Alabama                                                      NaN
#           Alaska                                                       NaN
#           Arizona                                                      NaN
#           Arkansas                                                     NaN
#           California                                                   NaN
# ...                                                                    ...
# 2022      Virginia                                               35.825000
#           Washington                                             32.088235
#           West Virginia                                          30.088889
#           Wisconsin                                              34.541667
#           Wyoming                                                24.144444
#
# Question                 Percentage of older adult women who have received a mammogram within the past 2 years  \
# YearStart LocationDesc
# 2015      Alabama                                                      NaN
#           Alaska                                                       NaN
#           Arizona                                                      NaN
#           Arkansas                                                     NaN
#           California                                                   NaN
# ...                                                                    ...
# 2022      Virginia                                               76.653846
#           Washington                                             71.884211
#           West Virginia                                          73.177778
#           Wisconsin                                              79.635714
#           Wyoming                                                62.710000
#
# Question                 Percentage of older adult women with an intact cervix who had a Pap test within the past 3 years  \
# YearStart LocationDesc
# 2015      Alabama                                                      NaN
#           Alaska                                                       NaN
#           Arizona                                                      NaN
#           Arkansas                                                     NaN
#           California                                                   NaN
# ...                                                                    ...
# 2022      Virginia                                               42.116667
#           Washington                                             37.493750
#           West Virginia                                          38.555556
#           Wisconsin                                              45.016667
#           Wyoming                                                34.144444
#
# Question                 Percentage of older adults currently not providing care who expect to provide care for someone with health problems in the next two years  \
# YearStart LocationDesc
# 2015      Alabama                                                19.340000
#           Alaska                                                       NaN
#           Arizona                                                      NaN
#           Arkansas                                                     NaN
#           California                                                   NaN
# ...                                                                    ...
# 2022      Virginia                                               14.606250
#           Washington                                             15.565000
#           West Virginia                                                NaN
#           Wisconsin                                              13.791667
#           Wyoming                                                      NaN
#
# Question                 Percentage of older adults ever told they have arthritis  \
# YearStart LocationDesc
# 2015      Alabama                                                52.350000
#           Alaska                                                 40.333333
#           Arizona                                                39.780000
#           Arkansas                                               49.137500
#           California                                             37.168182
# ...                                                                    ...
# 2022      Virginia                                               43.982353
#           Washington                                             43.845833
#           West Virginia                                          60.715385
#           Wisconsin                                              47.084211
#           Wyoming                                                46.007692
#
# Question                 ...  \
# YearStart LocationDesc   ...
# 2015      Alabama        ...
#           Alaska         ...
#           Arizona        ...
#           Arkansas       ...
#           California     ...
# ...                      ...
# 2022      Virginia       ...
#           Washington     ...
#           West Virginia  ...
#           Wisconsin      ...
#           Wyoming        ...
#
# Question                 Percentage of older adults who report having lost 5 or fewer teeth due to decay or gum disease  \
# YearStart LocationDesc
# 2015      Alabama                                                      NaN
#           Alaska                                                       NaN
#           Arizona                                                      NaN
#           Arkansas                                                     NaN
#           California                                                   NaN
# ...                                                                    ...
# 2022      Virginia                                               79.563158
#           Washington                                             79.512500
#           West Virginia                                          58.992308
#           Wisconsin                                              75.331579
#           Wyoming                                                75.107692
#
# Question                 Percentage of older adults who reported binge drinking within the past 30 days  \
# YearStart LocationDesc
# 2015      Alabama                                                 7.035714
#           Alaska                                                 13.669231
#           Arizona                                                 8.285714
#           Arkansas                                                7.536364
#           California                                              9.417647
# ...                                                                    ...
# 2022      Virginia                                                9.306667
#           Washington                                              9.858824
#           West Virginia                                           8.616667
#           Wisconsin                                              12.876923
#           Wyoming                                                10.691667
#
# Question                 Percentage of older adults who reported influenza vaccine within the past year  \
# YearStart LocationDesc
# 2015      Alabama                                                51.412500
#           Alaska                                                 44.193333
#           Arizona                                                43.389474
#           Arkansas                                               47.800000
#           California                                             50.376190
# ...                                                                    ...
# 2022      Virginia                                               59.078947
#           Washington                                             59.437500
#           West Virginia                                          55.592308
#           Wisconsin                                              57.911111
#           Wyoming                                                47.423077
#
# Question                 Percentage of older adults who self-reported that their health is "fair" or "poor"  \
# YearStart LocationDesc
# 2015      Alabama                                                32.362500
#           Alaska                                                 21.780000
#           Arizona                                                29.626316
#           Arkansas                                               36.625000
#           California                                             27.276190
# ...                                                                    ...
# 2022      Virginia                                               21.417647
#           Washington                                             23.687500
#           West Virginia                                          34.384615
#           Wisconsin                                              24.950000
#           Wyoming                                                20.438462
#
# Question                 Percentage of older adults who self-reported that their health is "good", "very good", or "excellent"  \
# YearStart LocationDesc
# 2015      Alabama                                                67.637500
#           Alaska                                                 78.220000
#           Arizona                                                71.455000
#           Arkansas                                               63.375000
#           California                                             73.450000
# ...                                                                    ...
# 2022      Virginia                                               79.100000
#           Washington                                             76.312500
#           West Virginia                                          65.615385
#           Wisconsin                                              75.294737
#           Wyoming                                                79.561538
#
# Question                 Percentage of older adults with a lifetime diagnosis of depression  \
# YearStart LocationDesc
# 2015      Alabama                                                22.612500
#           Alaska                                                 16.121429
#           Arizona                                                20.441176
#           Arkansas                                               23.392857
#           California                                             14.800000
# ...                                                                    ...
# 2022      Virginia                                               17.460000
#           Washington                                             19.508333
#           West Virginia                                          23.750000
#           Wisconsin                                              18.344444
#           Wyoming                                                17.358333
#
# Question                 Percentage of older adults with subjective cognitive decline or memory loss who reported talking with a health care professional about it  \
# YearStart LocationDesc
# 2015      Alabama                                                44.006667
#           Alaska                                                       NaN
#           Arizona                                                40.838462
#           Arkansas                                               38.353846
#           California                                             43.736364
# ...                                                                    ...
# 2022      Virginia                                               47.223077
#           Washington                                                   NaN
#           West Virginia                                                NaN
#           Wisconsin                                              44.616667
#           Wyoming                                                      NaN
#
# Question                 Percentage of older adults without diabetes who reported a blood sugar or diabetes test within 3 years  \
# YearStart LocationDesc
# 2015      Alabama                                                67.700000
#           Alaska                                                 62.673333
#           Arizona                                                      NaN
#           Arkansas                                                     NaN
#           California                                                   NaN
# ...                                                                    ...
# 2022      Virginia                                                     NaN
#           Washington                                                   NaN
#           West Virginia                                          91.241667
#           Wisconsin                                              91.677778
#           Wyoming                                                83.376923
#
# Question                 Physically unhealthy days (mean number of days in past month)  \
# YearStart LocationDesc
# 2015      Alabama                                                 6.250000
#           Alaska                                                  4.953333
#           Arizona                                                 5.622222
#           Arkansas                                                6.531250
#           California                                              5.240909
# ...                                                                    ...
# 2022      Virginia                                                5.006250
#           Washington                                              5.266667
#           West Virginia                                           7.092308
#           Wisconsin                                               5.311765
#           Wyoming                                                 5.084615
#
# Question                 Severe joint pain due to arthritis among older adults with doctor-diagnosed arthritis
# YearStart LocationDesc
# 2015      Alabama                                                40.873333
#           Alaska                                                       NaN
#           Arizona                                                31.493333
#           Arkansas                                               37.173333
#           California                                             34.283333
# ...                                                                    ...
# 2022      Virginia                                                     NaN
#           Washington                                                   NaN
#           West Virginia                                                NaN
#           Wisconsin                                                    NaN
#           Wyoming                                                      NaN
#
# [425 rows x 36 columns]
